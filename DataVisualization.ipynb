# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('fenerbahce_beko_cleaned.csv')
df.head(5)
# Out:
#            Opposing Team  IsHome  Points  Performance Index Rating  \
# 0   Kinder London Towers       1   107.0                     143.0
# 1               Zalgiris       0    82.0                      66.0
# 2  Kinder Virtus Bologna       0    60.0                      42.0
# 3         Union Olimpija       1    75.0                      72.0
# 4         Opel Skyliners       0    70.0                      51.0
#
#    Two-point %  Three-point %  Free-throw %  Offensive rebounds  \
# 0         70.8           36.8          64.3                11.0
# 1         42.0           52.6          52.6                17.0
# 2         44.2           25.0          58.3                11.0
# 3         59.5           14.3          65.5                19.0
# 4         42.2           33.3          66.7                16.0
#
#    Defensive rebounds  Total rebounds  Assists  Steals  Blocks  Turnovers  \
# 0                27.0            38.0     21.0    16.0     1.0       14.0
# ...

# %%
df.isnull().sum()
# Out:
# Opposing Team               0
# IsHome                      0
# Points                      0
# Performance Index Rating    0
# Two-point %                 0
# Three-point %               0
# Free-throw %                0
# Offensive rebounds          0
# Defensive rebounds          0
# Total rebounds              0
# Assists                     0
# Steals                      0
# Blocks                      0
# Turnovers                   0
# Day                         0
# Month                       0
# Year                        0
# Date                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Opposing Team             629 non-null    object
#  1   IsHome                    629 non-null    int64
#  2   Points                    629 non-null    float64
#  3   Performance Index Rating  629 non-null    float64
#  4   Two-point %               629 non-null    float64
#  5   Three-point %             629 non-null    float64
#  6   Free-throw %              629 non-null    float64
#  7   Offensive rebounds        629 non-null    float64
#  8   Defensive rebounds        629 non-null    float64
#  9   Total rebounds            629 non-null    float64
#  10  Assists                   629 non-null    float64
#  11  Steals                    629 non-null    float64
#  12  Blocks                    629 non-null    float64
# ...

# %%
df.describe()
# Out:
#            IsHome      Points  Performance Index Rating  Two-point %  \
# count  629.000000  629.000000                629.000000   629.000000
# mean     0.502385   78.507154                 84.755167    53.701590
# std      0.500392   11.324064                 20.972848     9.097051
# min      0.000000   43.000000                 27.000000    25.800000
# 25%      0.000000   71.000000                 71.000000    47.800000
# 50%      1.000000   78.000000                 86.000000    53.300000
# 75%      1.000000   86.000000                 99.000000    59.500000
# max      1.000000  118.000000                155.000000    85.300000
#
#        Three-point %  Free-throw %  Offensive rebounds  Defensive rebounds  \
# count     629.000000    629.000000          629.000000          629.000000
# mean       37.308426     74.212242            9.685215           22.465819
# std        10.878094     12.462256            3.595307            4.406227
# ...

# %%
sns.scatterplot(data=df , x="Points", y="Performance Index Rating", hue="IsHome")
plt.xlabel("Sayı")
plt.ylabel("Verimlilik")
plt.title("Sayı vs Verimlilik")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=df, x="Three-point %", y="Performance Index Rating", hue="IsHome")
plt.xlabel("Üçlük Yüzdesi")
plt.ylabel("Verimlilik")
plt.title("Üçlük Yüzdesi vs Verimlilik")
plt.show()

# %%
sns.set_style("darkgrid")
sns.lmplot(data=df, x="Two-point %", y="Performance Index Rating", hue="IsHome")
plt.xlabel("İkilik Yüzdesi")
plt.ylabel("Verimlilik")
plt.title("İkilik Yüzdesi vs Verimlilik")
plt.show()

# %%
sns.set_style("dark")
sns.lmplot(data=df, x="Free-throw %", y="Performance Index Rating", height=5)
plt.xlabel("Serbest Atış Yüzdesi")
plt.ylabel("Verimlilik")
plt.title("Serbest Atış Yüzdesi vs Verimlilik")
plt.show()

# %%
sns.set_style("whitegrid")
sns.kdeplot(df['Performance Index Rating'], fill=True, color='red')
plt.title('Verimlilik Puanı Dağılımı')
plt.xlabel('Verimlilik')
plt.ylabel('Yoğunluk')
plt.show()

# %%
sns.set_style("white")
plt.figure(figsize=(13,6))

plt.subplot(1,3,1)
sns.boxplot(df["Blocks"])
plt.title("Blok")

plt.subplot(1,3,2)
sns.boxplot(df["Steals"])
plt.title("Top Çalma")

plt.subplot(1,3,3)
sns.boxplot(df["Turnovers"])
plt.title("Top Kaybı")

plt.tight_layout()
plt.show()

# %%
sns.countplot(x="IsHome", data=df, palette='pastel', hue="IsHome", legend=False)
plt.xticks([0,1], ["Away", "Home"])
plt.title("Ev Sahibi vs Deplasman")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Korelasyon Matrisi")
plt.show()

# %%
corr = df.corr(numeric_only=True)[["Performance Index Rating"]].sort_values("Performance Index Rating", ascending=False)[1:]

plt.figure(figsize=(4,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Verimlilik Puanı')
plt.show()

# %%
top10 = df['Opposing Team'].value_counts().head(10)

plt.figure(figsize=(8,8))
plt.pie(top10, labels=top10.index, autopct='%1.1f%%', startangle=140)
plt.title("FBB' nin En Çok Karşılaştığı 10 Takım", loc="center")
plt.show()
